# %%
import pandas as pd
import os
import re

# %%
filelist = os.listdir('./project_data/covert_coor_to_dong/univ')
filelist
# Out:
# ['culture_dong.csv',
#  'hanriver_dong.csv',
#  'health_facility_dong.csv',
#  'park_dong.csv',
#  'road_for_people.csv',
#  'school_dong.csv',
#  'tourlist_dong.csv',
#  'univ_dong.csv']

# %%
filelist
# Out:
# ['culture_dong.csv',
#  'hanriver_dong.csv',
#  'health_facility_dong.csv',
#  'road_for_people.csv',
#  'school_dong.csv',
#  'tourlist_dong.csv',
#  'univ_dong.csv']

# %%
park = pd.read_csv('./project_data/covert_coor_to_dong/park_dong.csv', sep=',' ,encoding='utf-8',engine='python')
park.rename(columns={'Unnamed: 0':'행정동'},inplace=True)
park
# Out:
#             행정동  공원개수     구
# 0          가양1동     2   강서구
# 1          고덕2동     1   강동구
# 2          고척2동     1   구로구
# 3           고촌읍     1   김포시
# 4           교남동     1   종로구
# 5         금호4가동     1   성동구
# 6         노량진1동     1   동작구
# 7           녹번동     1   은평구
# 8         답십리2동     1  동대문구
# 9          도곡1동     1   강남구
# 10         도곡2동     1   강남구
# 11         돈암1동     2   성북구
# 12         둔촌2동     1   강동구
# 13         등촌1동     1   강서구
# 14         마천2동     1   송파구
# 15          목2동     1   양천구
# 16         발산1동     1   강서구
# 17         방배2동     1   서초구
# 18         방배3동     1   서초구
# 19         방화3동     1   강서구
# 20          번2동     1   강북구
# 21         불광1동     1   은평구
# 22         불광2동     1   은평구
# 23         사당3동     1   동작구
# 24          사직동     2   종로구
# 25          삼양동     1   강북구
# 26          삼청동     1   종로구
# 27         상도4동     1   동작구
# 28          상일동     1   강동구
# 29          서원동     1   관악구
# ..          ...   ...   ...
# 31          세곡동     2   강남구
# ...

# %%
sum_total = pd.read_csv('./project_data/sum_of_8_range/sum_of_8_range.csv', sep=',' ,engine='python')

# %%
sum_total
# Out:
#      Unnamed: 0     행정동     구  공원개수  문화시설개수  한강공원개수  체육시설개수  보행자도로개수   초중고  \
# 0             0    가양1동   강서구   2.0     2.0     NaN     NaN      NaN   4.0
# 1             1    고덕2동   강동구   1.0     2.0     NaN     NaN      NaN   4.0
# 2             2    고척2동   구로구   1.0     2.0     NaN     NaN      NaN   4.0
# 3             4     교남동   종로구   1.0     1.0     NaN     NaN      NaN   2.0
# 4             5   금호4가동   성동구   1.0     NaN     NaN     NaN      NaN   2.0
# 5             6   노량진1동   동작구   1.0     1.0     NaN     NaN      4.0   4.0
# 6             7     녹번동   은평구   1.0     6.0     NaN     NaN      2.0   2.0
# 7             8   답십리2동  동대문구   1.0     2.0     NaN     1.0      NaN   2.0
# 8             9    도곡1동   강남구   1.0     1.0     NaN     NaN      NaN   2.0
# 9            10    도곡2동   강남구   1.0     2.0     NaN     NaN      NaN   4.0
# 10           11    돈암1동   성북구   2.0     NaN     NaN     NaN      NaN   4.0
# ...

# %%
a = pd.read_csv('./project_data/covert_coor_to_dong/univ_dong_final.csv', sep=',' ,encoding='utf-8', engine='python')
a.rename(columns={'Unnamed: 0':'행정동'},inplace=True)

# %%
a
# Out:
#        행정동  대학교개수     구
# 0     고척1동      1   구로구
# 1     공릉2동      2   노원구
# 2      광장동      1   광진구
# 3      군자동      1   광진구
# 4    남가좌2동      1  서대문구
# 5     논현2동      1   강남구
# 6      대학동      1   관악구
# 7      대흥동      1   마포구
# 8   면목3.8동      1   중랑구
# 9      미아동      2   강북구
# 10    반포4동      1   서초구
# 11    방배3동      1   서초구
# 12     부암동      1   종로구
# 13     사근동      2   성동구
# 14    사당3동      1   동작구
# 15     삼선동      1   성북구
# 16  상계6.7동      1   노원구
# 17    상도1동      1   동작구
# 18     서강동      1   마포구
# 19    서초1동      1   서초구
# 20     석관동      1   성북구
# 21    신사1동      1   은평구
# 22     신촌동      2  서대문구
# 23    쌍문1동      1   도봉구
# 24     안암동      1   성북구
# 25    오류2동      1   구로구
# 26     오륜동      1   송파구
# 27    월계1동      1   노원구
# 28    월계2동      1   노원구
# 29    월곡2동      1   성북구
# 30    이문1동      2  동대문구
# 31     이화동      1   종로구
# 32     장충동      1    중구
# 33    전농2동      1  동대문구
# 34    정릉3동      1   성북구
# 35    정릉4동      1   성북구
# 36   청운효자동      1   종로구
# ...

# %%
new_df = pd.merge(sum_total, a, how='outer', left_on = ['행정동','구'], right_on=['행정동','구'])

# %%
new_df
# Out:
#      Unnamed: 0     행정동     구  공원개수  문화시설개수  한강공원개수  체육시설개수  보행자도로개수   초중고  \
# 0             0    가양1동   강서구   2.0     2.0     NaN     NaN      NaN   4.0
# 1             1    고덕2동   강동구   1.0     2.0     NaN     NaN      NaN   4.0
# 2             2    고척2동   구로구   1.0     2.0     NaN     NaN      NaN   4.0
# 3             4     교남동   종로구   1.0     1.0     NaN     NaN      NaN   2.0
# 4             5   금호4가동   성동구   1.0     NaN     NaN     NaN      NaN   2.0
# 5             6   노량진1동   동작구   1.0     1.0     NaN     NaN      4.0   4.0
# 6             7     녹번동   은평구   1.0     6.0     NaN     NaN      2.0   2.0
# 7             8   답십리2동  동대문구   1.0     2.0     NaN     1.0      NaN   2.0
# 8             9    도곡1동   강남구   1.0     1.0     NaN     NaN      NaN   2.0
# 9            10    도곡2동   강남구   1.0     2.0     NaN     NaN      NaN   4.0
# 10           11    돈암1동   성북구   2.0     NaN     NaN     NaN      NaN   4.0
# ...

# %%
new_df.to_csv('./project_data/sum_of_8_range/sum_of_8_range.csv', sep=',', encoding='utf-8')

# %%
new_df = new_df[['행정동', '구', '공원개수',  '문화시설개수', '한강공원개수', '체육시설개수', '관광명소개수_x', '초중고',
       '관광명소개수_y', '대학교개수', '지하철개수','호텔개수','총합']]

# %%
del new_df['총합']

# %%
new_df['총합'] = new_df.sum(axis=1)

# %%
new_df
# Out:
#      Unnamed: 0     행정동     구  공원개수  문화시설개수  한강공원개수  체육시설개수  보행자도로개수   초중고  \
# 0             0    가양1동   강서구   2.0     2.0     NaN     NaN      NaN   4.0
# 1             1    고덕2동   강동구   1.0     2.0     NaN     NaN      NaN   4.0
# 2             2    고척2동   구로구   1.0     2.0     NaN     NaN      NaN   4.0
# 3             4     교남동   종로구   1.0     1.0     NaN     NaN      NaN   2.0
# 4             5   금호4가동   성동구   1.0     NaN     NaN     NaN      NaN   2.0
# 5             6   노량진1동   동작구   1.0     1.0     NaN     NaN      4.0   4.0
# 6             7     녹번동   은평구   1.0     6.0     NaN     NaN      2.0   2.0
# 7             8   답십리2동  동대문구   1.0     2.0     NaN     1.0      NaN   2.0
# 8             9    도곡1동   강남구   1.0     1.0     NaN     NaN      NaN   2.0
# 9            10    도곡2동   강남구   1.0     2.0     NaN     NaN      NaN   4.0
# 10           11    돈암1동   성북구   2.0     NaN     NaN     NaN      NaN   4.0
# ...
