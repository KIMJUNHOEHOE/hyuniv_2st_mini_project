# %%
import pandas as pd
import os
import re

# %%
filelist = os.listdir('./project_data/covert_coor_to_dong/')
filelist
# Out:
# ['culture_dong.csv',
#  'hanriver_dong.csv',
#  'health_facility_dong.csv',
#  'park_dong.csv',
#  'road_for_people.csv',
#  'school_dong.csv',
#  'tourlist_dong.csv',
#  'univ_dong.csv']

# %%
filelist
# Out:
# ['culture_dong.csv',
#  'hanriver_dong.csv',
#  'health_facility_dong.csv',
#  'road_for_people.csv',
#  'school_dong.csv',
#  'tourlist_dong.csv',
#  'univ_dong.csv']

# %%
park = pd.read_csv('./project_data/covert_coor_to_dong/park_dong.csv', sep=',' ,encoding='utf-8',engine='python')
park.rename(columns={'Unnamed: 0':'행정동'},inplace=True)
park
# Out:
#             행정동  공원개수     구
# 0          가양1동     2   강서구
# 1          고덕2동     1   강동구
# 2          고척2동     1   구로구
# 3           고촌읍     1   김포시
# 4           교남동     1   종로구
# 5         금호4가동     1   성동구
# 6         노량진1동     1   동작구
# 7           녹번동     1   은평구
# 8         답십리2동     1  동대문구
# 9          도곡1동     1   강남구
# 10         도곡2동     1   강남구
# 11         돈암1동     2   성북구
# 12         둔촌2동     1   강동구
# 13         등촌1동     1   강서구
# 14         마천2동     1   송파구
# 15          목2동     1   양천구
# 16         발산1동     1   강서구
# 17         방배2동     1   서초구
# 18         방배3동     1   서초구
# 19         방화3동     1   강서구
# 20          번2동     1   강북구
# 21         불광1동     1   은평구
# 22         불광2동     1   은평구
# 23         사당3동     1   동작구
# 24          사직동     2   종로구
# 25          삼양동     1   강북구
# 26          삼청동     1   종로구
# 27         상도4동     1   동작구
# 28          상일동     1   강동구
# 29          서원동     1   관악구
# ..          ...   ...   ...
# 31          세곡동     2   강남구
# 32          수궁동     1   구로구
# 33         신사1동     1   은평구
# 34         신사2동     1   은평구
# 35         신정3동     2   양천구
# 36         신정7동     1   양천구
# 37         쌍문4동     1   도봉구
# 38          약수동     1    중구
# 39         양재1동     1   서초구
# 40          연희동     2  서대문구
# 41          오금동     1   송파구
# 42         오류1동     1   구로구
# 43         오류2동     1   구로구
# 44          용강동     1   마포구
# 45        용산2가동     1   용산구
# 46         월곡1동     1   성북구
# 47         일원본동     1   강남구
# 48         잠실6동     1   송파구
# 49          장지동     1   송파구
# 50         전농2동     1  동대문구
# 51  종로1.2.3.4가동     1   종로구
# 52         중곡4동     1   광진구
# 53          진관동     4   은평구
# 54          창1동     1   도봉구
# 55          천연동     1  서대문구
# 56         청량리동     2  동대문구
# 57          혜화동     1   종로구
# 58         홍은2동     2  서대문구
# 59         화곡본동     1   강서구
# 60          흑석동     1   동작구
#
# [61 rows x 3 columns]

# %%
filelist
# Out:
# ['culture_dong.csv',
#  'hanriver_dong.csv',
#  'health_facility_dong.csv',
#  'road_for_people.csv',
#  'school_dong.csv',
#  'tourlist_dong.csv',
#  'univ_dong.csv']

# %%
a = pd.read_csv('./project_data/covert_coor_to_dong/hotel_dong.csv', sep=',' ,encoding='utf-8', engine='python')
a.rename(columns={'Unnamed: 0':'행정동'},inplace=True)

# %%
a
# Out:
#             행정동  호텔개수     구
# 0          가락본동     2   송파구
# 1           가산동     1   금천구
# 2          개포4동     1   강남구
# 3           공항동     1   강서구
# 4           광장동     2   광진구
# 5           광희동     8    중구
# 6          구로3동     2   구로구
# 7          구의3동     1   광진구
# 8           군자동     1   광진구
# 9            길동     2   강동구
# 10          남영동     3   용산구
# 11          녹번동     1   은평구
# 12         논현1동     7   강남구
# 13         논현2동     2   강남구
# 14         당산2동     2  영등포구
# 15         대치2동     1   강남구
# 16         대치4동     2   강남구
# 17          도화동     1   마포구
# 18         독산1동     1   금천구
# 19         독산4동     1   금천구
# 20          동선동     2   성북구
# 21         등촌1동     1   강서구
# 22         등촌2동     1   강서구
# 23         등촌3동     1   강서구
# 24           명동    18    중구
# 25         반포4동     2   서초구
# 26         발산1동     4   강서구
# 27         방이2동     1   송파구
# 28         방화2동     1   강서구
# 29          번1동     1   강북구
# ..          ...   ...   ...
# 68          용신동     3  동대문구
# 69         을지로동     4    중구
# 70         응암1동     1   은평구
# 71        이태원1동     4   용산구
# 72          인수동     1   강북구
# 73         자양3동     1   광진구
# 74         잠실3동     1   송파구
# 75         잠실본동     2   송파구
# 76          잠원동     2   서초구
# 77         장안1동     3  동대문구
# 78         장안2동     2  동대문구
# 79          장충동     4    중구
# 80         전농1동     2  동대문구
# 81  종로1.2.3.4가동    22   종로구
# 82      종로5.6가동     2   종로구
# 83          종암동     1   성북구
# 84         창신1동     3   종로구
# 85         천호2동     1   강동구
# 86          청담동     5   강남구
# 87         청량리동     1  동대문구
# 88          충현동     1  서대문구
# 89          평창동     1   종로구
# 90           필동     6    중구
# 91          한남동     2   용산구
# 92          합정동     1   마포구
# 93         홍은2동     1  서대문구
# 94         화곡1동     7   강서구
# 95         화곡6동     4   강서구
# 96          회현동     5    중구
# 97         휘경1동     1  동대문구
#
# [98 rows x 3 columns]

# %%
new_df = pd.merge(new_df, a, how='outer', left_on = ['행정동','구'], right_on=['행정동','구'])

# %%
new_df
# Out:
#         행정동        구  공원개수  문화시설개수  한강공원개수  체육시설개수  관광명소개수_x   초중고  관광명소개수_y  \
# 0      가양1동      강서구   2.0     2.0     NaN     NaN       NaN   4.0       1.0
# 1      고덕2동      강동구   1.0     2.0     NaN     NaN       NaN   4.0       NaN
# 2      고척2동      구로구   1.0     2.0     NaN     NaN       NaN   4.0       NaN
# 3       고촌읍      김포시   1.0     NaN     NaN     NaN       NaN   NaN       NaN
# 4       교남동      종로구   1.0     1.0     NaN     NaN       NaN   2.0       NaN
# 5     금호4가동      성동구   1.0     NaN     NaN     NaN       NaN   2.0       NaN
# 6     노량진1동      동작구   1.0     1.0     NaN     NaN       4.0   4.0       NaN
# 7       녹번동      은평구   1.0     6.0     NaN     NaN       2.0   2.0       NaN
# 8     답십리2동     동대문구   1.0     2.0     NaN     1.0       NaN   2.0       NaN
# 9      도곡1동      강남구   1.0     1.0     NaN     NaN       NaN   2.0       NaN
# 10     도곡2동      강남구   1.0     2.0     NaN     NaN       NaN   4.0       NaN
# 11     돈암1동      성북구   2.0     NaN     NaN     NaN       NaN   4.0       NaN
# 12     둔촌2동      강동구   1.0     NaN     NaN     1.0       NaN   5.0       NaN
# 13     등촌1동      강서구   1.0     NaN     NaN     NaN       NaN   1.0       NaN
# 14     마천2동      송파구   1.0     NaN     NaN     NaN       2.0   1.0       NaN
# 15      목2동      양천구   1.0     NaN     NaN     NaN       4.0   1.0       NaN
# 16     발산1동      강서구   1.0     NaN     NaN     NaN       NaN  14.0       NaN
# 17     방배2동      서초구   1.0     NaN     NaN     NaN       2.0   2.0       NaN
# 18     방배3동      서초구   1.0     NaN     NaN     NaN       NaN   1.0       NaN
# 19     방화3동      강서구   1.0     1.0     NaN     NaN       2.0   6.0       NaN
# 20      번2동      강북구   1.0     2.0     NaN     NaN       NaN   1.0       NaN
# 21     불광1동      은평구   1.0     2.0     NaN     NaN       NaN   2.0       NaN
# 22     불광2동      은평구   1.0     NaN     NaN     NaN       2.0   7.0       NaN
# 23     사당3동      동작구   1.0     NaN     NaN     NaN       NaN   2.0       NaN
# 24      사직동      종로구   2.0    17.0     NaN     1.0       NaN   3.0       5.0
# 25      삼양동      강북구   1.0     1.0     NaN     NaN       NaN   5.0       NaN
# 26      삼청동      종로구   1.0    15.0     NaN     NaN       2.0   2.0       1.0
# 27     상도4동      동작구   1.0     NaN     NaN     NaN       NaN   3.0       NaN
# 28      상일동      강동구   1.0     1.0     NaN     NaN       NaN   8.0       NaN
# 29      서원동      관악구   1.0     NaN     NaN     NaN       4.0   1.0       NaN
# ..      ...      ...   ...     ...     ...     ...       ...   ...       ...
# 413    홍제1동     서대문구   NaN     NaN     NaN     NaN       NaN   2.0       NaN
# 414    홍제3동     서대문구   NaN     NaN     NaN     NaN       NaN   3.0       NaN
# 415    화곡1동      강서구   NaN     NaN     NaN     NaN       NaN   3.0       NaN
# 416    화곡2동      강서구   NaN     NaN     NaN     NaN       NaN   1.0       NaN
# 417    화곡4동      강서구   NaN     NaN     NaN     NaN       NaN   4.0       NaN
# 418     화전동  고양시 덕양구   NaN     NaN     NaN     NaN       NaN   2.0       NaN
# 419    휘경2동     동대문구   NaN     NaN     NaN     NaN       NaN   7.0       NaN
# 420    가정1동       서구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 421    가좌3동       서구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 422    가좌4동       서구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 423    구월2동      남동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 424    방배1동      서초구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 425    부개2동      부평구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 426    사당4동      동작구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 427    성내2동      강동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 428  성수1가2동      성동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 429    수유2동      강북구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 430     신포동       중구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 431     양서면      양평군   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 432     양평읍      양평군   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 433    연수2동      연수구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 434     영종동       중구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 435    옥련2동      연수구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 436    용현2동     미추홀구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 437     운서동       중구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 438   장수서창동      남동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 439    주안4동     미추홀구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 440    중화2동      중랑구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 441    홍제2동     서대문구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 442    휘경1동     동대문구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
#
#      대학교개수  지하철개수    총합  호텔개수
# 0      NaN    3.0  12.0   NaN
# 1      NaN    NaN   7.0   NaN
# 2      NaN    NaN   7.0   NaN
# 3      NaN    NaN   1.0   NaN
# 4      NaN    NaN   4.0   NaN
# 5      NaN    1.0   4.0   NaN
# 6      NaN    2.0  12.0   NaN
# 7      NaN    2.0  13.0   1.0
# 8      NaN    NaN   6.0   NaN
# 9      NaN    1.0   5.0   NaN
# 10     NaN    1.0   8.0   NaN
# 11     NaN    NaN   6.0   NaN
# 12     NaN    NaN   7.0   NaN
# 13     NaN    1.0   3.0   1.0
# 14     NaN    NaN   4.0   NaN
# 15     NaN    1.0   7.0   NaN
# 16     NaN    2.0  17.0   4.0
# 17     NaN    1.0   6.0   NaN
# 18     NaN    1.0   3.0   NaN
# 19     NaN    1.0  11.0   NaN
# 20     NaN    NaN   4.0   NaN
# 21     NaN    1.0   6.0   2.0
# 22     NaN    NaN  10.0   NaN
# 23     1.0    NaN   4.0   NaN
# 24     NaN    2.0  30.0   NaN
# 25     NaN    2.0   9.0   NaN
# 26     NaN    NaN  21.0   NaN
# 27     NaN    NaN   4.0   NaN
# 28     NaN    1.0  11.0   NaN
# 29     NaN    NaN   6.0   NaN
# ..     ...    ...   ...   ...
# 413    1.0    NaN   3.0   NaN
# 414    NaN    1.0   4.0   NaN
# 415    NaN    2.0   5.0   7.0
# 416    NaN    NaN   1.0   NaN
# 417    NaN    NaN   4.0   NaN
# 418    NaN    NaN   2.0   NaN
# 419    1.0    NaN   8.0   NaN
# 420    NaN    1.0   1.0   NaN
# 421    NaN    1.0   1.0   NaN
# 422    NaN    1.0   1.0   NaN
# 423    NaN    1.0   1.0   NaN
# 424    NaN    1.0   1.0   NaN
# 425    NaN    1.0   1.0   NaN
# 426    NaN    1.0   1.0   NaN
# 427    NaN    2.0   2.0   1.0
# 428    NaN    1.0   1.0   NaN
# 429    NaN    1.0   1.0   1.0
# 430    NaN    1.0   1.0   NaN
# 431    NaN    1.0   1.0   NaN
# 432    NaN    1.0   1.0   NaN
# 433    NaN    1.0   1.0   NaN
# 434    NaN    1.0   1.0   NaN
# 435    NaN    1.0   1.0   NaN
# 436    NaN    1.0   1.0   NaN
# 437    NaN    1.0   1.0   NaN
# 438    NaN    1.0   1.0   NaN
# 439    NaN    1.0   1.0   NaN
# 440    NaN    1.0   1.0   NaN
# 441    NaN    1.0   1.0   NaN
# 442    NaN    1.0   1.0   1.0
#
# [443 rows x 13 columns]

# %%
new_df.to_csv('./project_data/sum_of_8_range/sum_of_8_range.csv', sep=',', encoding='utf-8')

# %%
new_df = new_df[['행정동', '구', '공원개수',  '문화시설개수', '한강공원개수', '체육시설개수', '관광명소개수_x', '초중고',
       '관광명소개수_y', '대학교개수', '지하철개수','호텔개수','총합']]

# %%
del new_df['총합']

# %%
new_df['총합'] = new_df.sum(axis=1)

# %%
new_df
# Out:
#         행정동        구  공원개수  문화시설개수  한강공원개수  체육시설개수  관광명소개수_x   초중고  관광명소개수_y  \
# 0      가양1동      강서구   2.0     2.0     NaN     NaN       NaN   4.0       1.0
# 1      고덕2동      강동구   1.0     2.0     NaN     NaN       NaN   4.0       NaN
# 2      고척2동      구로구   1.0     2.0     NaN     NaN       NaN   4.0       NaN
# 3       고촌읍      김포시   1.0     NaN     NaN     NaN       NaN   NaN       NaN
# 4       교남동      종로구   1.0     1.0     NaN     NaN       NaN   2.0       NaN
# 5     금호4가동      성동구   1.0     NaN     NaN     NaN       NaN   2.0       NaN
# 6     노량진1동      동작구   1.0     1.0     NaN     NaN       4.0   4.0       NaN
# 7       녹번동      은평구   1.0     6.0     NaN     NaN       2.0   2.0       NaN
# 8     답십리2동     동대문구   1.0     2.0     NaN     1.0       NaN   2.0       NaN
# 9      도곡1동      강남구   1.0     1.0     NaN     NaN       NaN   2.0       NaN
# 10     도곡2동      강남구   1.0     2.0     NaN     NaN       NaN   4.0       NaN
# 11     돈암1동      성북구   2.0     NaN     NaN     NaN       NaN   4.0       NaN
# 12     둔촌2동      강동구   1.0     NaN     NaN     1.0       NaN   5.0       NaN
# 13     등촌1동      강서구   1.0     NaN     NaN     NaN       NaN   1.0       NaN
# 14     마천2동      송파구   1.0     NaN     NaN     NaN       2.0   1.0       NaN
# 15      목2동      양천구   1.0     NaN     NaN     NaN       4.0   1.0       NaN
# 16     발산1동      강서구   1.0     NaN     NaN     NaN       NaN  14.0       NaN
# 17     방배2동      서초구   1.0     NaN     NaN     NaN       2.0   2.0       NaN
# 18     방배3동      서초구   1.0     NaN     NaN     NaN       NaN   1.0       NaN
# 19     방화3동      강서구   1.0     1.0     NaN     NaN       2.0   6.0       NaN
# 20      번2동      강북구   1.0     2.0     NaN     NaN       NaN   1.0       NaN
# 21     불광1동      은평구   1.0     2.0     NaN     NaN       NaN   2.0       NaN
# 22     불광2동      은평구   1.0     NaN     NaN     NaN       2.0   7.0       NaN
# 23     사당3동      동작구   1.0     NaN     NaN     NaN       NaN   2.0       NaN
# 24      사직동      종로구   2.0    17.0     NaN     1.0       NaN   3.0       5.0
# 25      삼양동      강북구   1.0     1.0     NaN     NaN       NaN   5.0       NaN
# 26      삼청동      종로구   1.0    15.0     NaN     NaN       2.0   2.0       1.0
# 27     상도4동      동작구   1.0     NaN     NaN     NaN       NaN   3.0       NaN
# 28      상일동      강동구   1.0     1.0     NaN     NaN       NaN   8.0       NaN
# 29      서원동      관악구   1.0     NaN     NaN     NaN       4.0   1.0       NaN
# ..      ...      ...   ...     ...     ...     ...       ...   ...       ...
# 413    홍제1동     서대문구   NaN     NaN     NaN     NaN       NaN   2.0       NaN
# 414    홍제3동     서대문구   NaN     NaN     NaN     NaN       NaN   3.0       NaN
# 415    화곡1동      강서구   NaN     NaN     NaN     NaN       NaN   3.0       NaN
# 416    화곡2동      강서구   NaN     NaN     NaN     NaN       NaN   1.0       NaN
# 417    화곡4동      강서구   NaN     NaN     NaN     NaN       NaN   4.0       NaN
# 418     화전동  고양시 덕양구   NaN     NaN     NaN     NaN       NaN   2.0       NaN
# 419    휘경2동     동대문구   NaN     NaN     NaN     NaN       NaN   7.0       NaN
# 420    가정1동       서구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 421    가좌3동       서구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 422    가좌4동       서구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 423    구월2동      남동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 424    방배1동      서초구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 425    부개2동      부평구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 426    사당4동      동작구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 427    성내2동      강동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 428  성수1가2동      성동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 429    수유2동      강북구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 430     신포동       중구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 431     양서면      양평군   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 432     양평읍      양평군   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 433    연수2동      연수구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 434     영종동       중구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 435    옥련2동      연수구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 436    용현2동     미추홀구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 437     운서동       중구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 438   장수서창동      남동구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 439    주안4동     미추홀구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 440    중화2동      중랑구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 441    홍제2동     서대문구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
# 442    휘경1동     동대문구   NaN     NaN     NaN     NaN       NaN   NaN       NaN
#
#      대학교개수  지하철개수  호텔개수    총합
# 0      NaN    3.0   NaN  12.0
# 1      NaN    NaN   NaN   7.0
# 2      NaN    NaN   NaN   7.0
# 3      NaN    NaN   NaN   1.0
# 4      NaN    NaN   NaN   4.0
# 5      NaN    1.0   NaN   4.0
# 6      NaN    2.0   NaN  12.0
# 7      NaN    2.0   1.0  14.0
# 8      NaN    NaN   NaN   6.0
# 9      NaN    1.0   NaN   5.0
# 10     NaN    1.0   NaN   8.0
# 11     NaN    NaN   NaN   6.0
# 12     NaN    NaN   NaN   7.0
# 13     NaN    1.0   1.0   4.0
# 14     NaN    NaN   NaN   4.0
# 15     NaN    1.0   NaN   7.0
# 16     NaN    2.0   4.0  21.0
# 17     NaN    1.0   NaN   6.0
# 18     NaN    1.0   NaN   3.0
# 19     NaN    1.0   NaN  11.0
# 20     NaN    NaN   NaN   4.0
# 21     NaN    1.0   2.0   8.0
# 22     NaN    NaN   NaN  10.0
# 23     1.0    NaN   NaN   4.0
# 24     NaN    2.0   NaN  30.0
# 25     NaN    2.0   NaN   9.0
# 26     NaN    NaN   NaN  21.0
# 27     NaN    NaN   NaN   4.0
# 28     NaN    1.0   NaN  11.0
# 29     NaN    NaN   NaN   6.0
# ..     ...    ...   ...   ...
# 413    1.0    NaN   NaN   3.0
# 414    NaN    1.0   NaN   4.0
# 415    NaN    2.0   7.0  12.0
# 416    NaN    NaN   NaN   1.0
# 417    NaN    NaN   NaN   4.0
# 418    NaN    NaN   NaN   2.0
# 419    1.0    NaN   NaN   8.0
# 420    NaN    1.0   NaN   1.0
# 421    NaN    1.0   NaN   1.0
# 422    NaN    1.0   NaN   1.0
# 423    NaN    1.0   NaN   1.0
# 424    NaN    1.0   NaN   1.0
# 425    NaN    1.0   NaN   1.0
# 426    NaN    1.0   NaN   1.0
# 427    NaN    2.0   1.0   3.0
# 428    NaN    1.0   NaN   1.0
# 429    NaN    1.0   1.0   2.0
# 430    NaN    1.0   NaN   1.0
# 431    NaN    1.0   NaN   1.0
# 432    NaN    1.0   NaN   1.0
# 433    NaN    1.0   NaN   1.0
# 434    NaN    1.0   NaN   1.0
# 435    NaN    1.0   NaN   1.0
# 436    NaN    1.0   NaN   1.0
# 437    NaN    1.0   NaN   1.0
# 438    NaN    1.0   NaN   1.0
# 439    NaN    1.0   NaN   1.0
# 440    NaN    1.0   NaN   1.0
# 441    NaN    1.0   NaN   1.0
# 442    NaN    1.0   1.0   2.0
#
# [443 rows x 13 columns]
